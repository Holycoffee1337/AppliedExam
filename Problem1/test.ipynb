# %%
from models import TrainVAE, TrainAE,TrainCNN, TrainVAE2
image_model = TrainVAE()
image_model.run(1)
model = TrainCNN(image_model= image_model, image_type = "VAE_encode")
model.run(1)
# Out:
# Epoch: 0, Test set variational lower bound: -18336.669921875
# 82/82 [==============================] - 7s 70ms/step - loss: 0.6981 - accuracy: 0.4979 - val_loss: 0.6895 - val_accuracy: 0.5549

# %%
image_model.plot(1)
